# %%
import numpy as np
#import cmath
import math
#import random
#import sympy as sp
import matplotlib.pyplot as plt

# %%
# Create the data
axlimx = 2.1
axlimy = 2.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

# Latex style in text
plt.rcParams['text.usetex'] = True

# %%
axlimx = 2.1
axlimy = 2.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

for t in np.arange(-1,1,0.1):
    Fxy =  Y - 2*X*t + t**2
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

Exy = Y - X**2
plt.contour(X, Y, Exy, levels=[0], colors='magenta')
plt.gca().set_aspect('equal')
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.title(r'$F(x, y, t) = y - 2xt + t^2$', fontsize='12')

plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\odr.pdf")

# %%
# Create the contour plot
axlimx = 5.1
axlimy = 5.1
x = np.linspace(-axlimx, axlimx, 200)
y = np.linspace(-axlimy, axlimy, 200)
X, Y = np.meshgrid(x, y)

#resultant = 191102976*X**(10) + 262144*X**8*Y**6 - 9584640*X**8*Y**4 + 83165184*X**8*Y**2 - 633470976*X**8 - 16384*X**6*Y**(10) - 81920*X**6*Y**8 - 14483456*X**6*Y**6 - 113311744*X**6*Y**4 + 96419840*X**6*Y**2 + 698368000*X**6 - 16384*X**4*Y**(12) - 294912*X**4*Y**(10) - 2998272*X**4*Y**8 - 18284544*X**4*Y**6 - 74956800*X**4*Y**4 - 184320000*X**4*Y**2 - 256000000*X**4
resultant = 191102976*X**10 + 262144*X**8*Y**6 - 9584640*X**8*Y**4 + 83165184*X**8*Y**2 - 633470976*X**8 - 16384*X**6*Y**10 - 81920*X**6*Y**8 - 14483456*X**6*Y**6 - 113311744*X**6*Y**4 + 96419840*X**6*Y**2 + 698368000*X**6 - 16384*X**4*Y**12 - 294912*X**4*Y**10 - 2998272*X**4*Y**8 - 18284544*X**4*Y**6 - 74956800*X**4*Y**4 - 184320000*X**4*Y**2 - 256000000*X**4

for t in np.arange(-2,2,0.1):
    Fxy = X**2/(t**2+1)**2+(Y-2*t)**2-1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

plt.contour(X, Y, resultant, levels=[0], colors='magenta')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = \frac{x^2}{(t^2+1)^2}+(y-2t)^2-1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\resultant.pdf")

# %%
# Create the contour plot
axlimx = 5.1
axlimy = 5.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

for t in np.arange(-2,2,0.1):
    Fxy = X**2/(t**2+1)**2+(Y-2*t)**2-1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = \frac{x^2}{(t^2+1)^2}+(y-2t)^2-1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\too_complicated_equations.pdf")

# %%
# Create the contour plot
axlimx = 3.1
axlimy = 3.1
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)

for t in np.arange(0,2*math.pi,0.1):
    Fxy = X*math.cos(t) + Y*math.sin(t) - 1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

t = 0
Fxy = X*math.cos(t) + Y*math.sin(t) - 1
plt.contour(X, Y, Fxy, levels=[0], colors='blue')

t = math.pi/2
Fxy = X*math.cos(t) + Y*math.sin(t) - 1
plt.contour(X, Y, Fxy, levels=[0], colors='red')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = \cos tx + \sin ty - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\lines_in_normal_form.pdf")

# %%
axlimx = 1.6
axlimy = 1.6
x = np.linspace(-axlimx, axlimx, 100)
y = np.linspace(-axlimy, axlimy, 100)
X, Y = np.meshgrid(x, y)
count = 0

# Create the contour plot
for t in np.arange(0.1,2,0.1):
    Fxy = X**2 + Y**2  - t
    plt.contour(X, Y, Fxy, levels=[0], colors='black')
    count +=1

print(count)
# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = x^2 + y^2 - t$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\concentric_circles.pdf")
# Out:
# 19

# %%
# Create the contour plot
for t in np.arange(-1,1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system.pdf")

# %%
# Create the contour plot
for t in np.arange(-0.9,1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

Fxy = (X+1)**2 + Y**2  - 1
plt.contour(X, Y, Fxy, levels=[0], colors='blue')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\one_element_of_system.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\one_element_of_system.pdf")

# %%
# Create the contour plot
for t in np.arange(-1,1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

# Create an array of y values, all equal to 1
y1 = np.full(x.shape, 1)

# Create an array of y values, all equal to -1
y2 = np.full(x.shape, -1)

# Mask the y values outside of the desired range
y1_masked = np.where(np.logical_and(x >= -1, x <= 1), y1, np.nan)
y2_masked = np.where(np.logical_and(x >= -1, x <= 1), y2, np.nan)

# Plot the lines
plt.plot(x, y1_masked, label='y = 1', color='magenta')
plt.plot(x, y2_masked, label='y = -1', color='magenta')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system_with_correct_envelope.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system_with_correct_envelope.pdf")

# %%
# Create the contour plot
for t in np.arange(-1,1,0.1):
    Fxy = (X-t)**2 + Y**2  - 1
    plt.contour(X, Y, Fxy, levels=[0], colors='black')

Exy1 = Y - 1
Exy2 = Y + 1
plt.contour(X, Y, Exy1, levels=[0], colors='magenta')
plt.contour(X, Y, Exy2, levels=[0], colors='magenta')

# Add labels and title
plt.xlabel('$x$', fontsize='12')
plt.ylabel('$y$', fontsize='12')
plt.gca().set_aspect('equal')
plt.title(r'$F(x, y, t) = (x-t)^2 + y^2 - 1$', fontsize='12')

# Save the plot as a PDF file
#plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system_with_envelope_unlimited_domain.svg")
plt.savefig("C:\\Users\\tutko\\Desktop\\latex\\Diplomka\\images\\system_with_envelope_unlimited_domain.pdf")
